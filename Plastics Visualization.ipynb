# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data1= pd.read_excel(r"C:\Users\Lakshya Pokharna\OneDrive\Desktop\production.xlsx")

# %%
data1
# Out:
#   Performance plastics production volume in India FY 2015-2021  \
# 0                                            FY 2015
# 1                                            FY 2016
# 2                                            FY 2017
# 3                                            FY 2018
# 4                                            FY 2019
# 5                                            FY 2020
# 6                                            FY 2021
#
#    Production volume of performance plastics in India from financial year 2015 to 2021 in 1,000 metric tons
# 0                                               1591
# 1                                               1700
# 2                                               1799
# 3                                               1719
# 4                                               1589
# 5                                               1672
# 6                                               1520

# %%
data2= pd.read_excel(r"C:\Users\Lakshya Pokharna\OneDrive\Desktop\consumption_of_plastic.xlsx")

# %%
data2
# Out:
#    Year  Plastic consumption in India from 1990 to 2018 in tonnes
# 0  1990                                                900
# 1  1995                                               1650
# 2  2000                                               2800
# 3  2005                                               4200
# 4  2010                                               6800
# 5  2016                                              15500
# 6  2018                                              18450

# %%
data3= pd.read_excel(r"C:\Users\Lakshya Pokharna\OneDrive\Desktop\Limitation_of_plastic.xlsx")

# %%
data3
# Out:
#   Plastic Packaging Category LIMIT IN %  2021-22  2022-23  2023-24
# 0                            Category I       50       60       70
# 1                           Category II       40       50       60
# 2                          Category III       30       40       50

# %%
#Since we are planning to initiate an alternative of Plastic we have nearly no data of the new product.
#But we can visualize a scenario where the plastic usage is decreasing to make sure that our product is working well

# %%
plt.figure(figsize=(20,10))
print(sns.barplot(y=data1['Production volume of performance plastics in India from financial year 2015 to 2021 in 1,000 metric tons'], x=data1['Performance plastics production volume in India FY 2015-2021']))
plt.title('Production of Plastic',fontsize = 20)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5, 1.0, 'Production of Plastic')

# %%
plt.figure(figsize=(20,10))
print(sns.barplot(y=data2['Plastic consumption in India from 1990 to 2018 in tonnes'], x=data2['Year']))
plt.title('Consumption of Plastic',fontsize = 20)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5, 1.0, 'Consumption of Plastic')

# %%
plt.figure(figsize=(10,5))
print(sns.barplot(x=data3['Plastic Packaging Category LIMIT IN %'], y=data3['2021-22']))
plt.title('Limitation of Plastic',fontsize = 20)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5, 1.0, 'Limitation of Plastic')

# %%
plt.figure(figsize=(10,5))
print(sns.barplot(x=data3['Plastic Packaging Category LIMIT IN %'], y=data3['2022-23']))
plt.title('Limitation of Plastic',fontsize = 20)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5, 1.0, 'Limitation of Plastic')

# %%
plt.figure(figsize=(10,5))
print(sns.barplot(x=data3['Plastic Packaging Category LIMIT IN %'], y=data3['2023-24']))
plt.title('Limitation of Plastic',fontsize = 20)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5, 1.0, 'Limitation of Plastic')

# %%
plt.rcParams["figure.figsize"] = [9, 5]
plt.rcParams["figure.autolayout"] = True

df = pd.DataFrame(dict(data=[900, 1650, 2800, 4200, 6800, 15500, 18450]))
fig, ax = plt.subplots()

df['data'].plot(kind='bar', color='red')
df['data'].plot(kind='line', marker='*', color='black', ms=10)
plt.title('Consumption of Plastic',fontsize = 20)

plt.show()

# %%
plt.rcParams["figure.figsize"] = [9, 5]
plt.rcParams["figure.autolayout"] = True

df = pd.DataFrame(dict(data=[1591, 1700, 1799, 1719, 1589, 1672, 1520]))
fig, ax = plt.subplots()

df['data'].plot(kind='bar', color='purple')
df['data'].plot(kind='line', marker='d', color='black', ms=10)
plt.title('Production of Plastic',fontsize = 20)

plt.show()
